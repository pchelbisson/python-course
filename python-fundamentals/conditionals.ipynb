# %% [markdown]
# # If / Elif / Else Logic
#
# Control the flow of scripts based on conditions using `if`, `elif`, and `else`.

# %% [markdown]
# ## The `if` Statement
#
# An `if` statement executes a block of code only if a condition is `True`.
#
# - Syntax: `if <condition>:` followed by an indented block
# - Comparison operators: `==`, `!=`, `<`, `>`, `<=`, `>=`, `in`
# - Combine conditions with `and`, `or`, `not`

# %%
errors = ['warn', 'err', 'crit']
if errors:
    print('System has issues!')
else:
    print('System is healthy!')
# Out:
# System has issues!
# WARNING: High CPU usage.

# %% [markdown]
# ### Truthiness
#
# Python treats many values as truthy or falsy in conditionals.
#
# - **Falsy**: `False`, `None`, `0`, `0.0`, `''`, `[]`, `{}`
# - **Truthy**: non-zero numbers, non-empty sequences/collections

# %% [markdown]
# ## The `else` statement
#
# Use `else` to execute code when the `if` condition is false.

# %% [markdown]
# ## The `elif` statement
#
# Chain multiple checks; the first true block runs.

# %%
cpu_usage = 85
if cpu_usage > 90:
    print("CRITICAL: CPU is too high!")
elif cpu_usage > 70 and cpu_usage < 91:
    print("WARNING: High CPU usage.")
else:
    print("OK: CPU usage is normal.")

# %% [markdown]
# ## Guard Clauses
#
# Handle edge cases at the top of functions to avoid deep nesting of `if` conditions.

# %%
api_key = ""
env = "prod"
if not api_key:
    print("Error: No API key found!")
elif env == 'prod':
    print("Deploying to production...")
else:
    print("Deploying to staging...")
# Out:
# Error: No API key found!

# %%
server_state = {'status': 'active', 'free_space_gb': 5}
if server_state['status'] != 'active':
    print("Server is down")
else:
    print("Server is active!")
    if server_state['free_space_gb'] < 10:
        print("Warning: Low disk space")
    else:
        print("Server is ready for deploy")
# Out:
# Server is active!
# Warning: Low disk space
